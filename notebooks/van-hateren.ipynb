# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import matplotlib.pyplot as plt
import svis
import numpy as np

# %%
from transform_datasets.patterns.natural import VanHateren, VanHaterenSlices

# %%
pattern = VanHateren(path="/home/sanborn/datasets/van-hateren/", min_contrast=0.1, patches_per_image=3, patch_size=8)

# %%
pattern2 = VanHaterenSlices(path="/home/sanborn/datasets/van-hateren/", 
                     min_contrast=0.1, 
                     patches_per_image=3,
                     patch_size=8)

# %%
pattern2.data.shape
# Out:
# torch.Size([103, 8])

# %%
plt.figure(figsize=(10, 10))
plt.imshow(pattern2.data[:20], cmap="Greys_r")
plt.colorbar()

# %%
svis.image_grid(pattern.data[:100], shape=(10, 10), figsize=(15, 15), cmap="Greys_r", share_range=False)

# %%
pattern.data[0].std()
# Out:
# tensor(0.0489, dtype=torch.float64)
