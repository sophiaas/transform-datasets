# %%
# %load_ext autoreload
# %autoreload 2
import torch
from transform_datasets.patterns.natural import MNISTExemplars
from transform_datasets.transforms import CyclicTranslation2D
from transform_datasets.dataset import TransformDataset
import svis
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pattern = MNISTExemplars(path="/home/sanborn/datasets/mnist/mnist_train.csv")
transformation = CyclicTranslation2D(fraction_transforms=1.0)
dataset = TransformDataset(pattern, transformation)

# %%
svis.image_grid(pattern.data, shape=(2, 5))

# %%
dataset.data.shape
# Out:
# torch.Size([7840, 28, 28])

# %%
7840/28/3
# Out:
# 93.33333333333333

# %%
svis.image_grid(dataset.data[600:700])
